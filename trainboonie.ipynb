# %%
# !wget https://raw.githubusercontent.com/Foxy6670/ggmlagent/main/train_boonie_14b.py
# Out:
# --2026-06-24 01:25:57--  https://raw.githubusercontent.com/Foxy6670/ggmlagent/main/train_boonie_14b.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4555 (4.4K) [text/plain]
# Saving to: ‘train_boonie_14b.py’
#
# train_boonie_14b.py 100%[===================>]   4.45K  --.-KB/s    in 0s
#
# 2026-06-24 01:25:57 (57.6 MB/s) - ‘train_boonie_14b.py’ saved [4555/4555]

# %%
# !pip install unsloth trl datasets -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.3/60.3 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 MB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 37.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 43.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 14.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 915.6/915.6 MB 1.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 82.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 73.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 51.1 MB/s eta 0:00:00
# ...

# %%
# !python train_boonie_14b.py
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2026.6.9: Fast Qwen3 patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors.index.json: 100% 172k/172k [00:00<00:00, 216MB/s]
# ...
#
# ...
# Fetching 2 files: 100% 2/2 [03:51<00:00, 115.67s/it]
# Download complete: 100% 9.93G/9.93G [03:51<00:00, 42.9MB/s]
# Loading weights: 100% 443/443 [00:40<00:00, 10.99it/s]
# generation_config.json: 100% 237/237 [00:00<00:00, 1.32MB/s]
# config.json: 100% 1.33k/1.33k [00:00<00:00, 595kB/s]
# ...

# %%
# !du / 2>/dev/null | sort -rh | head -20
# Out:
# 93165472	/
# 38642276	/usr
# 31102940	/usr/local
# 30711552	/content
# 29117868	/content/boonie_14b
# 28855712	/content/boonie_14b/gguf
# 23666640	/usr/local/lib
# 22155696	/usr/local/lib/python3.12
# 22155688	/usr/local/lib/python3.12/dist-packages
# 21097864	/root
# 11910856	/root/.cache
# 9716420	/root/.cache/huggingface
# 9696372	/root/.cache/huggingface/hub
# 9696288	/root/.cache/huggingface/hub/models--unsloth--Qwen3-14B-bnb-4bit
# 9696252	/root/.cache/huggingface/hub/models--unsloth--Qwen3-14B-bnb-4bit/blobs
# 9044080	/root/.julia
# 7800448	/root/.julia/artifacts
# 6855112	/usr/local/cuda-12.8
# 6259260	/usr/local/cuda-12.8/targets
# 6259256	/usr/local/cuda-12.8/targets/x86_64-linux

# %%
# !ls -l /content/boonie_14b/gguf
# Out:
# total 28855660
# -rw-r--r-- 1 root root       4673 Jun 24 01:59 chat_template.jinja
# -rw-r--r-- 1 root root       1943 Jun 24 01:59 config.json
# -rw-r--r-- 1 root root        210 Jun 24 01:59 generation_config.json
# -rw-r--r-- 1 root root 4984780784 Jun 24 02:36 model-00001-of-00006.safetensors
# -rw-r--r-- 1 root root 4980892048 Jun 24 02:39 model-00002-of-00006.safetensors
# -rw-r--r-- 1 root root 4928485104 Jun 24 02:42 model-00003-of-00006.safetensors
# -rw-r--r-- 1 root root 4980892112 Jun 24 02:45 model-00004-of-00006.safetensors
# -rw-r--r-- 1 root root 4928485104 Jun 24 02:47 model-00005-of-00006.safetensors
# -rw-r--r-- 1 root root 4733130504 Jun 24 02:49 model-00006-of-00006.safetensors
# -rw-r--r-- 1 root root      36514 Jun 24 01:59 model.safetensors.index.json
# -rw-r--r-- 1 root root      10150 Jun 24 01:59 tokenizer_config.json
# -rw-r--r-- 1 root root   11423114 Jun 24 01:59 tokenizer.json

# %%
# !rm -rf /root/.cache/huggingface
# !rm -rf /root/.cache/pip
# !rm -rf /root/.julia

# %%
# !find / -name "convert_hf_to_gguf.py" 2>/dev/null | head -3
# !find / -name "llama-quantize" 2>/dev/null | head -3
# Out:
# /root/.unsloth/llama.cpp/convert_hf_to_gguf.py
# /root/.unsloth/llama.cpp/llama-quantize

# %%
# !python /root/.unsloth/llama.cpp/convert_hf_to_gguf.py \
    /content/boonie_14b/gguf/ \
    --outtype f16 \
    --outfile /content/boonie.F16.gguf
# Out:
# INFO:hf-to-gguf:Loading model: gguf
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:hf-to-gguf:Model architecture: Qwen3ForCausalLM
# INFO:hf-to-gguf:gguf: loading model weight map from 'model.safetensors.index.json'
# INFO:hf-to-gguf:gguf: indexing model part 'model-00001-of-00006.safetensors'
# INFO:hf-to-gguf:gguf: indexing model part 'model-00002-of-00006.safetensors'
# INFO:hf-to-gguf:gguf: indexing model part 'model-00003-of-00006.safetensors'
# INFO:hf-to-gguf:gguf: indexing model part 'model-00004-of-00006.safetensors'
# INFO:hf-to-gguf:gguf: indexing model part 'model-00005-of-00006.safetensors'
# INFO:hf-to-gguf:gguf: indexing model part 'model-00006-of-00006.safetensors'
# INFO:gguf.gguf_writer:gguf: This GGUF file is for Little Endian only
# INFO:hf-to-gguf:Exporting model...
# INFO:hf-to-gguf:token_embd.weight,         torch.bfloat16 --> F16, shape = {5120, 151936}
# INFO:hf-to-gguf:blk.0.attn_norm.weight,    torch.bfloat16 --> F32, shape = {5120}
# ...

# %%
# !rm /content/boonie_14b/gguf/model-*.safetensors

# %%
# !/root/.unsloth/llama.cpp/llama-quantize \
    /content/boonie.F16.gguf \
    /content/boonie_14b/boonie-14b-Q6_K.gguf \
    Q6_K
# Out:
# load_backend: loaded RPC backend from /root/.unsloth/llama.cpp/libggml-rpc.so
# load_backend: loaded CPU backend from /root/.unsloth/llama.cpp/libggml-cpu-skylakex.so
# llama_print_build_info: build = 9773 (751d7f7b6)
# llama_print_build_info: built with GNU 11.4.0 for Linux x86_64 (Compiled by the Unsloth team)
# llama_quantize: quantizing '/content/boonie.F16.gguf' to '/content/boonie_14b/boonie-14b-Q6_K.gguf' as Q6_K
# llama_model_loader: loaded meta data with 30 key-value pairs and 443 tensors from /content/boonie.F16.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = qwen3
# llama_model_loader: - kv   1:                               general.type str              = model
# llama_model_loader: - kv   2:                     general.sampling.top_k i32              = 20
# ...

# %%
# !cat /content/boonie_14b/boonie-14b-Q6_K.gguf | nc 216.220.250.61 9999
# Out:
#
#
# ^C

# %%
# !md5sum /content/boonie_14b/boonie-14b-Q6_K.gguf
# Out:
# 927b57558af7d096610a9e72f0cf5ff9  /content/boonie_14b/boonie-14b-Q6_K.gguf
